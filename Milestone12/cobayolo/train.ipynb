# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

# %%
results = model.train(
    data="/home/veevry/loky_ws/cobayolo/new_yolo.v1-roboflow-instant-1--eval-.yolov8/data.yaml",
    epochs=200,         # bisa disesuaikan
    imgsz=512,         # ukuran gambar
    batch=16,          # batch size (sesuaikan dengan GPU/RAM-mu)
    project="runs/train",
    name="vision"
)
# Out:
# Ultralytics 8.3.252 🚀 Python-3.12.3 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 5804MiB)
# ...

# %%
val_results = model.val(data="/home/veevry/loky_ws/cobayolo/new_yolo.v1-roboflow-instant-1--eval-.yolov8/data.yaml")
# Out:
# Ultralytics 8.3.252 🚀 Python-3.12.3 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 5804MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2673.7±446.4 MB/s, size: 553.3 KB)
# val: Scanning /home/veevry/loky_ws/cobayolo/new_yolo.v1-roboflow-instant-1--eval-.yolov8/valid/labels.cache... 4 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4/4 1.5Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.6it/s 0.3s
#                    all          4         14      0.986          1      0.995      0.837
#                  dummy          4         11      0.997          1      0.995      0.779
#            real_person          2          3      0.974          1      0.995      0.895
# Speed: 0.3ms preprocess, 18.6ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to /home/veevry/loky_ws/cobayolo/runs/detect/val2

# %%
results = model.predict(source="/home/veevry/loky_ws/cobayolo/new_yolo.v1-roboflow-instant-1--eval-.yolov8/test/images", conf=0.25)
# Out:
# image 1/4 /home/veevry/loky_ws/cobayolo/new_yolo.v1-roboflow-instant-1--eval-.yolov8/test/images/IMG_20260112_141655_jpg.rf.2f0daf72b59894a01201825195b4b7a7.jpg: 512x320 2 dummys, 1 real_person, 37.3ms
# image 2/4 /home/veevry/loky_ws/cobayolo/new_yolo.v1-roboflow-instant-1--eval-.yolov8/test/images/IMG_20260112_141705_jpg.rf.c1059bac343448395a26e1b02451f077.jpg: 512x320 2 dummys, 1 real_person, 2.5ms
# image 3/4 /home/veevry/loky_ws/cobayolo/new_yolo.v1-roboflow-instant-1--eval-.yolov8/test/images/IMG_20260112_142055_jpg.rf.2398ed3912028f52a9a00afbe99a424d.jpg: 512x320 2 dummys, 1 real_person, 2.5ms
# image 4/4 /home/veevry/loky_ws/cobayolo/new_yolo.v1-roboflow-instant-1--eval-.yolov8/test/images/IMG_20260112_142141_jpg.rf.2cdb18a7313f7d2290e0876bdaf94c26.jpg: 512x320 2 dummys, 1 real_person, 2.5ms
# Speed: 1.5ms preprocess, 11.2ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 320)
